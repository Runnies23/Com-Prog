# %%
data = open("./file/wave1/firstfive.txt").read().splitlines()
data = [int(i) for i in data if int(i) % 5 == 0]

# %%
data
# Out:
# [968140, 619960, 970725, 76090, 657540]

# %%
data = open("./file/wave1/snowfall.txt").read().splitlines()
data
# Out:
# ['921',
# ...

# %%
# data[0] = 10
# seq = [int(i) for i in "-3 -2 -1 0 1 0 -1 -2 -3".split()]

# %%
lenght = int(data[0])
seq = [int(i) for i in data[1].split(" ")]
lenght, seq
# Out:
# (921,
#  [2036,
#   211,
#   26292,
#   9574,
#   -26141,
#   12451,
#   3743,
#   -27160,
#   18808,
#   -11852,
#   -2318,
#   2402,
#   8140,
#   15173,
#   16811,
#   13097,
#   9718,
#   13324,
#   22773,
#   -8869,
#   -16805,
#   -11092,
#   -16237,
#   24392,
#   22824,
#   4071,
#   -13812,
#   14043,
#   -17625,
#   16967,
#   14608,
#   14411,
#   -12822,
#   23042,
#   -6016,
#   3180,
#   5493,
#   -20130,
#   6020,
#   6443,
#   -1982,
#   -26298,
#   -9013,
#   -11700,
#   -28983,
#   -22203,
#   -16461,
#   10735,
#   -26737,
#   -23689,
#   -28135,
#   -13542,
#   -4780,
#   -14372,
#   -7008,
#   -11957,
#   -28158,
#   9181,
#   -15772,
#   -3640,
#   -3853,
#   -19022,
#   -7086,
#   25468,
#   -25980,
#   29041,
#   -1352,
#   9513,
#   -21090,
#   -13190,
#   -1902,
#   19072,
#   -9488,
#   19085,
#   -22629,
#   3672,
#   26882,
#   -9089,
#   -15594,
#   -17713,
#   -2778,
#   -1585,
#   10888,
#   -25416,
#   26186,
#   -26121,
#   -7372,
#   -19830,
# ...

# %%
streak = 0
total = 0 
for i in range(lenght):
    
    if seq[i] <= 0:
        streak += 1 
    else: 
        streak = 0


    if streak >= 3:
        total += 1

# %%
total
# Out:
# 116
